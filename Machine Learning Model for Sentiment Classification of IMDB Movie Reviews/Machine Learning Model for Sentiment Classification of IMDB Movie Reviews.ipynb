# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
#
# # Reviewer's feedback v.1
#
# **Halo Azam**
#
# **Greetings from Chamdani**
#
# Terima kasih telah mengirimkan project kamu dengan ini kamu sudah memulai sebuah langkah yang luar biasa saat ini. Disini saya akan mereview proyek kamu ya.
#
# Saya akan memberikan beberapa komentar dan feedback seperti dibawah ini, **mohon jangan dipindah, dirubah, maupun dihapus ya :).**
#
# > Mohon diperhatikan bahwa apabila ada temuan atau kesalahan yang sama namun tidak ada komentar perbaikan disana, itu berarti kamu masih tetap harus memperbaikinya yaa.
#
# Komentar yang saya berikan akan muncul dalam warna hijau, kuning, atau pun merah seperti ini:
#
# </div>
#
# <div class="alert alert-success">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Bagus, semua berjalan lancar.
#
# </div>
#
# <div class="alert alert-warning">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Ada beberapa catatan.
#
# </div>
#
# <div class="alert alert-danger">
# <b>Chamdani's comment v.*</b> <a class="tocSkip"></a>
#
# Perlu beberapa perbaikan.
#
# </div>
#
# <div class="alert alert-info">
# <b>Chamdani's info v.1</b> <a class="tocSkip"></a>
#
# Catatan umum:
# * Fungsi `print` tidak diperlukan untuk mencetak suatu nilai
# * Lebih baik tulis kode pada bagian akhir cell code untuk menampilkan output tanpa `print`
# * Perintah soal yang ada dalam tanda kurung siku `[...]` sebaiknya dihilangkan
# * Sangat disarankan untuk menggunakan cell markdown untuk memberikan deskripsi temuan atau kesimpulan.
# * Tidak disarankan menggunakan cell code untuk memberikan penjelasan / deskripsi.
# * Untuk menghindari galat pada notebook project kamu. Batasi jumlah output yang dikeluarkan setiap kode dengan batas max 10 baris data.
#
# </div>
#
# <div style="border:solid gray 5px; padding: 20px" class="alert alert-warning">
#
# **INGATLAH**
# * Project kamu tidak akan bisa diterima bila kamu masih memiliki feedback berwarna merah.
# * Kamu hanya memiliki 3 kali kesempatan iterasi submission disetiap projectnya
# * Jika merasa kesulitan kamu dapat menuliskan responmu atas feedback saya menggunakan blok markdown warna biru dan kamu bisa mengirimkan project pada submission selanjutnya untuk mendapatkan jawaban / respon dari saya segera yaa
#
# Kamu dapat menjawab saya dengan menggunakan blok berwarna biru seperti ini
#
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Siap kak.
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-warning">
#
# # General feedback v.1 [Minor Improvement Needed]
#
# Terima kasih banyak telah mengirimkan proyek Anda!
#
# Secara keseluruhan, proyek Anda **SANGAT** mengesankan. Namun saya telah menemukan beberapa hal kecil yang bisa menjadi saran perbaikan agar proyek kamu menjadi lebih baik lagi.
#
# Saya telah meninggalkan komentar yang dapat membantu Anda dalam hal tersebut. Hal ini tidak berarti bahwa Anda telah melakukan sesuatu yang salah. Hal ini hanya berisi beberapa saran tentang bagaimana pekerjaan Anda dapat kembangkan lebih lanjut. Anda masih memiliki kesempatan untuk memperbaikinya dan jangan lupa untuk kembali kepada saya setelah perbaikan anda selesai.
#
# <br>
# Jika ada sesuatu yang membuat Anda bingung atau tidak mengerti. Tolong, jangan ragu untuk menghubungi tim mentor atau instruktur kamu yaa
#
# kamu juga bisa menghubungi saya melalui reply feedback di notebook ini yaa
#
# **TETAP SEMANGAT!!**
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px" class="alert alert-success">
#
# # General feedback v.2 *Project Accepted*
#
# Terima kasih banyak telah mengirimkan proyek Anda!
# <br>
#
# Secara keseluruhan, proyek Anda **SANGAT** mengesankan. Semoga apa yang kamu pelajari dalam project ini dapat membantu meningkatkan kemampuanmu. Pertahankan apa yang sudah bagus, dan tingkatkan apa yang menurutmu masih perlu ditingkatkan. Semoga berhasil pada project selanjutnya yaa :)
#
# **TETAP SEMANGAT!!**
#
# </div>

# %% [markdown]
# # Keterangan Tugas

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# **INGATLAH** pada setiap project, selain deskripsi proyek kamu juga harus memberikan pengantar proyek, daftar isi, dan tujuan proyek. Tepat seperti yang telah kami contohkan pada project pertama tentang Y-music.
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# ## Introduction

# %% [markdown]
# Film Junky Union, sebuah komunitas baru bagi penggemar film klasik sedang mengembangkan sistem untuk memfilter dan mengategorikan ulasan film. Misi utamanya adalah melatih model agar bisa mendeteksi ulasan negatif secara otomatis. Anda akan menggunakan *dataset* ulasan film IMBD dengan pelabelan polaritas untuk membuat sebuah model yang bisa mengklasifikasikan ulasan positif dan negatif. Model ini setidaknya harus memiliki skor F1 sebesar 0,85.
#
# ### Daftar Isi

# %% [markdown]
# 1. [Introduction](#Daftar_Isi)
# 2. [Inisialisasi](#Inisialisasi)
# 3. [Memuat Data](#Memuat_Data)
# 4. [EDA](#EDA)
# 5. [Prosedur_Evaluasi](#Prosedur_Evaluasi)
# 6. [Normalisasi](#Normalisasi)
# 7. [Pemisahan Train/Test](#Pemisahan_Train/Test)
# 8. [Bekerja dengan Model](#Bekerja_dengan_Model)
# 9. [Ulasan Saya](#Ulasan_Saya)
# 10.[Kesimpulan](#Kesimpulan)

# %% [markdown]
# ### Goal
# Tujuan dari project ini yaitu:
# 1. Membandingkan text processing NLTK, Spacy dan BERT dan dua jenis model LogisticRegression dan LGBMClassifier dalam melakukan proses klasifikasi ulasan negatif dan positif.
# 2. Menemukan model terbaik berdasarkan metrik akurasi, f1, dan roc-auc.
# 3. Menguji model-model tersebut dengan ulasan pribadi untuk memastikan model bekerja dengan baik serta melihat apabila terdapat miss dalam model.
#
# ### Step
# Langkah yang ditempuh untuk menyelesaikan project ini yaitu:
# 1. Memuat dan memahami data
# 2. Menganalisis dataset yang dimiliki termasuk melihat keseimbangan data
# 3. Melakaukan pre-processing data dan menyiapkan training dan test dataset
# 4. Melakukan text-processing yaitu tokeninsasi dan lemmatisasi dengan NLTK, Spacy, dan BERT
# 5. Menguji dan mengavulasi model
# 6. Menguji dengan ulasan pribadi/custom
#
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>
#
# ## Inisialisasi

# %%
import math

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

from tqdm.auto import tqdm

# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# %%
# baris berikutnya menyediakan grafik dengan kualitas yang lebih baik di layar HiDPI 

# %config InlineBackend.figure_format = 'retina'

plt.style.use('seaborn')

# ini untuk menggunakan progress_apply, baca lebih lanjut dihttps://pypi.org/project/tqdm/#pandas-integration
tqdm.pandas()

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Memuat data
#
# df_reviews = pd.read_csv('/datasets/imdb_reviews.tsv', sep='\t', dtype={'votes': 'Int64'})
#
# df_reviews.info()
#
# Kita memiliki 17 kolom dengan data sebanyak 47331 baris. Terdapat nilai hilang/Null value pada kolom **average_rating** dan **votes**. Karena nilainya kecil kita hilangkan dari dataset.
#
# df_reviews = df_reviews.dropna()
#
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>
#
# ## EDA
#
# Periksa jumlah film dan ulasan selama beberapa tahun.

# %%
fig, axs = plt.subplots(2, 1, figsize=(16, 8))

ax = axs[0]

dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
    ['start_year'].value_counts().sort_index()
dft1 = dft1.reindex(index=np.arange(dft1.index.min(), max(dft1.index.max(), 2021))).fillna(0)
dft1.plot(kind='bar', ax=ax)
ax.set_title('Jumlah Film Selama Beberapa Tahun')

ax = axs[1]

dft2 = df_reviews.groupby(['start_year', 'pos'])['pos'].count().unstack()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)

dft2.plot(kind='bar', stacked=True, label='#ulasan  (neg, pos)', ax=ax)

dft2 = df_reviews['start_year'].value_counts().sort_index()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2021))).fillna(0)
dft3 = (dft2/dft1).fillna(0)
axt = ax.twinx()
dft3.reset_index(drop=True).rolling(5).mean().plot(color='orange', label='ulasan per film (rata-rata selama 5 tahun)', ax=axt)

lines, labels = axt.get_legend_handles_labels()
ax.legend(lines, labels, loc='upper left')

ax.set_title('Jumlah Ulasan Selama Beberapa Tahun') 

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_50/4002959377.py in <module>
#       3 ax = axs[0]
#       4
# ----> 5 dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
#       6     ['start_year'].value_counts().sort_index()
#       7 dft1 = dft1.reindex(index=np.arange(dft1.index.min(), max(dft1.index.max(), 2021))).fillna(0)
#
# NameError: name 'df_reviews' is not defined

# %% [markdown]
# Periksa distribusi jumlah ulasan per film dengan penghitungan yang tepat dan KDE (hanya untuk mengetahui perbedaannya dari penghitungan yang tepat)
#
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

ax = axs[0]
dft = df_reviews.groupby('tconst')['review'].count() \
    .value_counts() \
    .sort_index()
dft.plot.bar(ax=ax)
ax.set_title('Plot batang #Ulasan Per Film')

ax = axs[1]
dft = df_reviews.groupby('tconst')['review'].count()
sns.kdeplot(dft, ax=ax)
ax.set_title('Plot KDE #Ulasan Per Film') 

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_50/1741673022.py in <module>
#       2
#       3 ax = axs[0]
# ----> 4 dft = df_reviews.groupby('tconst')['review'].count() \
#       5     .value_counts() \
#       6     .sort_index()
#
# NameError: name 'df_reviews' is not defined

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('Train set: distribusi peringkat')

ax = axs[1]
dft = df_reviews.query('ds_part == "test"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('Train set: distribusi peringkat')

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_50/2256064673.py in <module>
#       2
#       3 ax = axs[0]
# ----> 4 dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
#       5 dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
#       6 dft.plot.bar(ax=ax)
#
# NameError: name 'df_reviews' is not defined

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>
#
# Distribusi ulasan negatif dan positif selama bertahun-tahun untuk dua bagian *dataset*

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 8), gridspec_kw=dict(width_ratios=(2, 1), height_ratios=(1, 1)))

ax = axs[0][0]

dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('*Test set*: jumlah ulasan dari polaritas yang berbeda per tahun')

ax = axs[0][1]

dft = df_reviews.query('ds_part == "train"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('*Train set*: distribusi dari polaritas yang berbeda per film')

ax = axs[1][0]

dft = df_reviews.query('ds_part == "test"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('*Test set*: jumlah ulasan dari polaritas yang berbeda per tahun')

ax = axs[1][1]

dft = df_reviews.query('ds_part == "test"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('*Train set*: distribusi dari polaritas yang berbeda per film')

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_50/598892918.py in <module>
#       3 ax = axs[0][0]
#       4
# ----> 5 dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
#       6 dft.index = dft.index.astype('int')
#       7 dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2020))).fillna(0)
#
# NameError: name 'df_reviews' is not defined

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>
#
# ## Prosedur Evaluasi
#
# Menyusun evaluasi yang dapat digunakan untuk semua model dalam tugas ini secara rutin

# %%
import sklearn.metrics as metrics

def evaluate_model(model, train_features, train_target, test_features, test_target):
    
    eval_stats = {}
    
    fig, axs = plt.subplots(1, 3, figsize=(20, 6)) 
    
    for type, features, target in (('train', train_features, train_target), ('test', test_features, test_target)):
        
        eval_stats[type] = {}
    
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        # F1
        f1_thresholds = np.arange(0, 1.01, 0.05)
        f1_scores = [metrics.f1_score(target, pred_proba>=threshold) for threshold in f1_thresholds]
        
        # ROC
        fpr, tpr, roc_thresholds = metrics.roc_curve(target, pred_proba)
        roc_auc = metrics.roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        # PRC
        precision, recall, pr_thresholds = metrics.precision_recall_curve(target, pred_proba)
        aps = metrics.average_precision_score(target, pred_proba)
        eval_stats[type]['APS'] = aps
        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # Scor F1 
        ax = axs[0]
        max_f1_score_idx = np.argmax(f1_scores)
        ax.plot(f1_thresholds, f1_scores, color=color, label=f'{type}, max={f1_scores[max_f1_score_idx]:.2f} @ {f1_thresholds[max_f1_score_idx]:.2f}')
        # menetapkan persilangan untuk beberapa ambang batas
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(f1_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(f1_thresholds[closest_value_idx], f1_scores[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('threshold')
        ax.set_ylabel('F1')
        ax.legend(loc='lower center')
        ax.set_title(f'Skor F1') 

        # ROC
        ax = axs[1]    
        ax.plot(fpr, tpr, color=color, label=f'{type}, ROC AUC={roc_auc:.2f}')
        # menetapkan persilangan untuk beberapa ambang batas
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.plot([0, 1], [0, 1], color='grey', linestyle='--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc='lower center')        
        ax.set_title(f'Kurva ROC')
        
        # PRC
        ax = axs[2]
        ax.plot(recall, precision, color=color, label=f'{type}, AP={aps:.2f}')
        # menetapkan persilangan untuk beberapa ambang batas
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(pr_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(recall[closest_value_idx], precision[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('recall')
        ax.set_ylabel('precision')
        ax.legend(loc='lower center')
        ax.set_title(f'PRC')        

        eval_stats[type]['Akurasi'] = metrics.accuracy_score(target, pred_target)
        eval_stats[type]['F1'] = metrics.f1_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index=('Akurasi', 'F1', 'APS', 'ROC AUC'))
    
    print(df_eval_stats)
    
    return

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Normalisasi

# %% [markdown]
# Kita menganggap semua model di bawah menerima teks dalam huruf kecil dan tanpa angka, tanda baca, dll.

# %%
import re
def clearText(data):
    text = data['review'].lower()
    pattern = r"[^a-zA-Z]"
    splited = re.sub(pattern," ",text).split()
    return ' '.join(splited)

# %%
df_reviews['review_norm'] = df_reviews.apply(clearText, axis = 1)

# %%
df_reviews[['review','review_norm']].head()
# Out:
#                                               review  \
# 0  The pakage implies that Warren Beatty and Gold...
# 1  How the hell did they get this made?! Presenti...
# 2  There is no real story the film seems more lik...
# 3  Um .... a serious film about troubled teens in...
# 4  I'm totally agree with GarryJohal from Singapo...
#
#                                          review_norm
# 0  the pakage implies that warren beatty and gold...
# 1  how the hell did they get this made presenting...
# 2  there is no real story the film seems more lik...
# 3  um a serious film about troubled teens in sing...
# 4  i m totally agree with garryjohal from singapo...

# %% [markdown]
# Proses normalisasi teks berhasil dilakukan, simbol selain huruf latin berhasil dihilangkan dari teks.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Pemisahan Train / Test

# %% [markdown]
# Untungnya, seluruh *dataset* sudah dibagi menjadi *train/test*. Bendera yang sesuai adalah 'ds_part'.

# %%
df_reviews_train = df_reviews.query('ds_part == "train"').copy()
df_reviews_test = df_reviews.query('ds_part == "test"').copy()

train_target = df_reviews_train['pos']
test_target = df_reviews_test['pos']

print(df_reviews_train.shape)
print(df_reviews_test.shape)
# Out:
# (23796, 18)
# (23533, 18)

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Bekerja dengan Model

# %% [markdown]
# ### Model 0 - Konstan

# %%
from sklearn.dummy import DummyClassifier

# %%
dummy_model = DummyClassifier(strategy='constant', constant=1)

# %% [markdown]
# model_dummy = model_dummy.fit(df_reviews_train, train_target)

# %%
dummy_model.fit(df_reviews_train, train_target)
# Out:
# DummyClassifier(constant=1, strategy='constant')

# %%
evaluate_model(dummy_model, df_reviews_train, train_target, df_reviews_test, test_target)
# Out:
#          train  test
# Akurasi   0.50  0.50
# F1        0.67  0.67
# APS       0.50  0.50
# ROC AUC   0.50  0.50

# %% [markdown]
# Model DummyClassifier yang disetting memberikan hasil tetap 1 untuk seluruh input memberikan akurasi bernilai 0.5. Hal ini menunjukan jumlah kelas dalam dataset seimbang dimana jumlah kelas 0 dan 1 sama banyak atau mungkin hanya berbeda sedikit saja.
# Karakteristik khas lainnya dari DummyClassifier ialah nilai F1 yang tidak perubah seiring dengan perubahan treshold.
#
# Pada kurva ROC garis biru dan hijau berimpit pada garis diagonal, hal ini menunjukan model ini tidak lebih baik daripada menebak kelas secara acak.
#
# Pada grafik PRC menunjukan model tidak melakukan proses diskriminasi kelas dengan baik yang ditandai dengan penurunan linear nilai precision seiring dengan peningkatan recall. Pada kondisi ideal atau model yang baik, kurva seharusnya cenderung condong ke sisi kanan atas. Seperti pada hasil kurva PRC pada model-model setelah ini. Mari kita lihat nanti.

# %%
train_target.value_counts()
# Out:
# 0    11912
# 1    11884
# Name: pos, dtype: int64

# %% [markdown]
# Yup, benar jumlah kelas 0 dan 1 seimbang sehingga akurasnya bisa 50%.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 1 - NLTK, TF-IDF dan LR

# %% [markdown]
# TF-IDF

# %%
import nltk

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
tfidfvect_1 = TfidfVectorizer(stop_words = stop_words)

# %%
train_features_1 = tfidfvect_1.fit_transform(df_reviews_train.review_norm)
test_features_1 = tfidfvect_1.transform(df_reviews_test.review_norm)

# %%
print(train_features_1.shape)
print(test_features_1.shape)
# Out:
# (23796, 71531)
# (23533, 71531)

# %%
model_1 = LogisticRegression()
model_1.fit(train_features_1, train_target)
# Out:
# LogisticRegression()

# %%
evaluate_model(model_1, train_features_1, train_target, test_features_1, test_target)
# Out:
#          train  test
# Akurasi   0.94  0.88
# F1        0.94  0.88
# APS       0.98  0.95
# ROC AUC   0.98  0.95

# %% [markdown]
# Terjadi peningkatan akurasi dan nilai F1 yang signifikan pada model LogisticRegression dengan feature yang diproses dengan tokenisasi NTLK. Namun terjadi sedikit overfitting dimana, terdapat perbedaan yang noticable antara akurasi dan F1 training dan test. Untuk mendapatkan akurasi dan F1 tersebut nilai treshold optimal dapat dilihat pada kurva Skor F1 yaitu berkisar antara 0.45-0.55.
#
# Nilai APS (average precision score) yang dihasilkan juga cukup tinggi yaitu 0.98. Hal ini menunjukan model mampu memberikan nilai presisi yang tinggi dan konsisten untuk berbagai nilai recall.
#
# Nilai ROC yang tinggi (0.98) dan didukung oleh luasan dibawah kurva ROC yang besar menunjukan model sudah lebih baik untuk membedakan kelas dibandingkan dengan menebak kelas secara acak. Pada kurva model yang baik ditandai dengan kurva yang condong ke arah kiri atas.
#
# Secara overal model ini sudah jauh lebih baik dibandingkan dengan DummyClassifier dalam membedakan review yang benar-benar baik dan buruk.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 3 - spaCy, TF-IDF dan LR

# %%
import spacy

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def text_preprocessing_3(text):
    
    doc = nlp(text)
    #tokens = [token.lemma_ for token in doc if not token.is_stop]
    tokens = [token.lemma_ for token in doc]
    
    return ' '.join(tokens)

# %%
df_reviews_train['review_tokenized'] = df_reviews_train['review_norm'].progress_apply(text_preprocessing_3)
# Out:
#   0%|          | 0/23796 [00:00<?, ?it/s]

# %%
df_reviews_test['review_tokenized'] = df_reviews_test['review_norm'].progress_apply(text_preprocessing_3)
# Out:
#   0%|          | 0/23533 [00:00<?, ?it/s]

# %%
tfidfvect_3 = TfidfVectorizer(stop_words = stop_words)
train_features_3 = tfidfvect_3.fit_transform(df_reviews_train['review_tokenized'])
test_features_3 = tfidfvect_3.transform(df_reviews_test['review_tokenized'])

# %%
model_3 = LogisticRegression()
model_3.fit(train_features_3, train_target)
# Out:
# LogisticRegression()

# %%
evaluate_model(model_3, train_features_3, train_target, test_features_3, test_target)
# Out:
#          train  test
# Akurasi   0.93  0.88
# F1        0.93  0.88
# APS       0.98  0.95
# ROC AUC   0.98  0.95

# %% [markdown]
# Mengubah library NLTK menjadi Scapy tidak memberikan hasil yang berbeda jauh dengan NLTK, meskipun pada model ini digunakan proses lemmatisasi. Spacy dengan model LR memberikan akurasi 0.01 lebih rendah daripada NLTK. Namun tetap saja secara overal, model ini sudah jauh lebih baik dibandingkan dengan DummyClassifier.
#
# Nilai Threshold optimumnya pun tidak jauh berbeda yaitu berkisar antara 0.45-0.50.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 4 - spaCy, TF-IDF dan LGBMClassifier

# %%
from lightgbm import LGBMClassifier

# %%
model_4 = LGBMClassifier()
train_features_4 = train_features_3.copy()
test_features_4 = test_features_3.copy()

# %%
model_4.fit(train_features_4, train_target)
# Out:
# LGBMClassifier()

# %%
evaluate_model(model_4, train_features_4, train_target, test_features_4, test_target)
# Out:
#          train  test
# Akurasi   0.91  0.86
# F1        0.91  0.86
# APS       0.97  0.93
# ROC AUC   0.97  0.94

# %% [markdown]
# Model LGBClassifier memberikan akurasi training dan test yang lebih rendah 0.02 dari LogisticRegression. Mungkin nilainya akan meningkat apabila melakukan tunning hyperparameter. Kita akan coba learning_rate yang lebih rendah.

# %%
model_4b = LGBMClassifier(learning_rate = 0.3)
model_4b.fit(train_features_4, train_target)
# Out:
# LGBMClassifier(learning_rate=0.3)

# %%
evaluate_model(model_4b, train_features_4, train_target, test_features_4, test_target)
# Out:
#          train  test
# Akurasi   0.98  0.86
# F1        0.98  0.86
# APS       1.00  0.94
# ROC AUC   1.00  0.94

# %% [markdown]
# Akurasi meningkat tapi metrik lainnnya tetap. Sepertinya saya akan tetap menggunakan model sebelumnya agar cukup seimbang antara metrik training dan testnya.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ###  Model 9 - BERT dengan LR

# %%
import torch
import transformers

# %%
tokenizer = transformers.BertTokenizer.from_pretrained('bert-base-uncased')
config = transformers.BertConfig.from_pretrained('bert-base-uncased')
model = transformers.BertModel.from_pretrained('bert-base-uncased')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def BERT_text_to_embeddings(texts, max_length=512, batch_size=100, force_device=None, disable_progress_bar=False):
    
    ids_list = []
    attention_mask_list = []

    
    for input_text in tqdm(texts, disable=disable_progress_bar):
        ids = tokenizer.encode(input_text.lower(), add_special_tokens=True, truncation=True, max_length=max_length)
        padded = np.array(ids + [0]*(max_length - len(ids)))
        attention_mask = np.where(padded != 0, 1, 0)
        ids_list.append(padded)
        attention_mask_list.append(attention_mask)
    
    if force_device is not None:
        device = torch.device(force_device)
    else:
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
    model.to(device)
    if not disable_progress_bar:
        print(f'Menggunakan {device}.')
    

    embeddings = []

    for i in tqdm(range(math.ceil(len(ids_list)/batch_size)), disable=disable_progress_bar):
            
        ids_batch = torch.LongTensor(ids_list[batch_size*i:batch_size*(i+1)]).to(device)
        attention_mask_batch = torch.LongTensor(attention_mask_list[batch_size*i:batch_size*(i+1)]).to(device)
            
        with torch.no_grad():            
            model.eval()
            batch_embeddings = model(input_ids=ids_batch, attention_mask=attention_mask_batch)   
        embeddings.append(batch_embeddings[0][:,0,:].detach().cpu().numpy())
        
    return np.concatenate(embeddings)

# %%
# Perhatian! Menjalankan BERT untuk ribuan teks mungkin memakan waktu lama di CPU, setidaknya beberapa jam
#train_features_9 = BERT_text_to_embeddings(df_reviews_train['review_norm'], force_device=None)

#sudah saya lakukan dengan bantuan Google Colab, diisini kernelnya mati terus.
#file disimpan dengan nama review_embedded.npy
#file tersebut berisikan df_revires['review_norm'] yang telah di embedding dengan BERT

# %%
data_embed = np.load('review_embedded.npy')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_45/3318105514.py in <module>
# ----> 1 data_embed = np.load('review_embedded.npy')
#
# /opt/conda/lib/python3.9/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     415             own_fid = False
#     416         else:
# --> 417             fid = stack.enter_context(open(os_fspath(file), "rb"))
#     418             own_fid = True
#     419
#
# FileNotFoundError: [Errno 2] No such file or directory: 'review_embedded.npy'

# %%
train_features_9 = data_embed[df_reviews.ds_part == 'train']
test_features_9 = data_embed[df_reviews.ds_part != 'train']

# %%
print(train_features_9.shape)
print(test_features_9.shape)

print(train_target.shape)
print(test_target.shape)

# %%
model_9 = LogisticRegression()
model_9.fit(train_features_9, train_target)

# %%
evaluate_model(model_9, train_features_9, train_target, test_features_9, test_target)

# %% [markdown]
# Model LogisticRegression dengan text processing BERT menghasilkan model paling "fit" tidak overfitting maupun underfitting dimana nilai metrik training dan test perbedaanya sangat kecil. Sejauh ini, ini model yang dipilih.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 10 - BERT dengan LGBM

# %%
train_features_10 = train_features_9.copy()
test_features_10 = test_features_9.copy()

# %%
model_10 = LGBMClassifier()
model_10.fit(train_features_10, train_target)

# %%
evaluate_model(model_10, train_features_10, train_target, test_features_10, test_target)

# %% [markdown]
# Namun apabila menggantinya dengan model LGBMClassifier terjadi overfitting pada model ini. Nilai akurasi trainingnya meningkat namun test nya justru turun.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Ulasan Saya

# %%
# jangan ragu untuk menghapus ulasan ini dan mencoba modelmu sendiri terhadap ulasanmu, ini hanya sekadar contoh saja 
my_reviews = pd.DataFrame([
    'saya tidak begitu menyukainya, bukan jenis film kesukaan saya.', 
    'Membosankan, bahkan saya tidur di tengah-tengah film.', 
    'Filmnya sangat bagus, saya sangat suka',     
    'Bahkan para aktornya terlihat sangat tua dan tidak tertarik dengan filmnya, apakah mereka dibayar untuk bermain film. Sungguh tidak bermutu.', 
    'Saya tidak menyangka filmnya sebagus ini! Para penulis sungguh memperhatikan tiap detailnya', 
    'Film ini memiliki kelebihan dan kekurangan, tetapi saya merasa secara keseluruhan ini adalah film yang layak. Saya mungkin akan menontonnya lagi.', 
    'Beberapa lawakannya sungguh tidak lucu. Tidak ada satu pun lelucon yang berhasil, semua orang bertingkah menyebalkan, bahkan anak-anak pun tidak akan menyukai ini!', 
    'Menayangkan film ini di Netflix adalah langkah yang berani & saya sangat senang bisa menonton episode demi episode dari drama baru yang menarik dan cerdas ini.',
    'Film ini sangat bagus! meskipun ceritanya jelek kaya sampah', #ada kata2 bagus, ada juga jelek
    'Bagus', #satu kata
    'Jelek',
    'Saya lapar, pengen makan kambing guling', #review gak nyambung, tone buruk
    'Saya suka sekali bermain layang-layang, apalagi jika warna hitam, pasti bagus sekali', #gak nyambung, tone baik
    'bagus bagus bagus, sangat jelek',
    'jelek jelek jelek, sangat bagus'
], columns=['review'])

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Karena kode dilatih dengan dataset berbahasa inggris maka disini kamu juga harusnya menguji model dengan data berbahasa inggris
# Silahkan translate data diatas menjadi bahasa inggris
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Saya translate pakai Library googletrans ka, di step selanjutnya.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# Contoh di atas menggunakan bahasa Indonesia, sedangkan model kita dilatih menggunakan bahasa Inggris. Kita perlu ubah bahasanya terlebih dahulu.

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#      |████████████████████████████████| 55 kB 6.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 133 kB 47.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 51.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 42 kB 3.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 53 kB 5.1 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 6.9 MB/s  eta 0:00:01
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17415 sha256=35b55b6d88c293b11533b9c3c128616d1d7526ab693b22c3d6123e65cb495ec9
#   Stored in directory: /home/jovyan/.cache/pip/wheels/60/b3/27/d8aff3e2d5c2d0d97a117cdf0d5f13cd121e2c2b5fb49b55a0
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
# ...

# %%
from googletrans import Translator
def translate(data):
    text = data['review']
    translator = Translator()
    translation = translator.translate(text, src='id', dest='en').text
    return translation

# %%
my_reviews['translated'] = my_reviews.apply(translate, axis = 1)

# %%
my_reviews['review_norm'] = my_reviews['translated'].str.lower().str.replace('[^a-zA-Z]', ' ')
my_reviews
# Out:
# /tmp/ipykernel_45/1079021234.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   my_reviews['review_norm'] = my_reviews['translated'].str.lower().str.replace('[^a-zA-Z]', ' ')
#                                                review  \
# 0   saya tidak begitu menyukainya, bukan jenis fil...
# 1   Membosankan, bahkan saya tidur di tengah-tenga...
# 2              Filmnya sangat bagus, saya sangat suka
# 3   Bahkan para aktornya terlihat sangat tua dan t...
# 4   Saya tidak menyangka filmnya sebagus ini! Para...
# 5   Film ini memiliki kelebihan dan kekurangan, te...
# 6   Beberapa lawakannya sungguh tidak lucu. Tidak ...
# 7   Menayangkan film ini di Netflix adalah langkah...
# 8   Film ini sangat bagus! meskipun ceritanya jele...
# 9                                               Bagus
# 10                                              Jelek
# 11            Saya lapar, pengen makan kambing guling
# ...

# %% [markdown]
# Selanjutnya kita bisa menguji review di atas, untuk menguji semua model kita.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# # Model 2

# %%
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_1.predict_proba(tfidfvect_1.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.92:  i don t really like it  not my favorite type of film
# 0.03:  boring  even i slept in the middle of the film
# 0.71:  the film is very good  i really like it
# 0.17:  even the actors look very old and are not interested in the film  whether they are paid to play film
# 0.58:  i didn t expect the film as good as this the authors really pay attention to each detail
# 0.47:  this film has advantages and disadvantages  but i feel overall this is a decent film i might watch i
# 0.05:  some of the jokes are really not funny none of the jokes succeeded  everyone acted annoying  even ch
# 0.85:  showing indian films on netflix is a brave step and i am very happy to be able to watch episode afte
# 0.20:  this film is very good even though the story is ugly like trash
# 0.91:  good
# 0.00:  bad
# 0.36:  i m hungry  want to eat goat bolster
# 0.83:  i love playing kite  especially if it is black  it must be very good
# 0.66:  good good good  very ugly
# 0.24:  ugly ugly  very good

# %% [markdown]
# Beberapa ada yang miss baik itu FN pada contoh pertama. "I dont really like it ..." seharusnya mendapatkan probabilitas yang rendah. Ada juga review "I didnt except the film as good as ..." seharusnya ini adalah review yang sangat bagus namun hanya diberi probabilitas 0.58, ya tidak masalah sih kalau treshold-nya dibawah itu. Justru review yang tidak nyambung "I love playing kite ... " memiliki probabilitas yang tinggi, mungkin model ini menilai bad or good review berdasarkan ada atau tidaknya bad words. Selanjutnya bisa dikembangkan terlebih dahulu review yang asal-asal dan benar-benar review.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 3

# %%
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_3.predict_proba(tfidfvect_3.transform(texts.apply(lambda x: text_preprocessing_3(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.95:  i don t really like it  not my favorite type of film
# 0.01:  boring  even i slept in the middle of the film
# 0.91:  the film is very good  i really like it
# 0.15:  even the actors look very old and are not interested in the film  whether they are paid to play film
# 0.59:  i didn t expect the film as good as this the authors really pay attention to each detail
# 0.36:  this film has advantages and disadvantages  but i feel overall this is a decent film i might watch i
# 0.02:  some of the jokes are really not funny none of the jokes succeeded  everyone acted annoying  even ch
# 0.88:  showing indian films on netflix is a brave step and i am very happy to be able to watch episode afte
# 0.35:  this film is very good even though the story is ugly like trash
# 0.99:  good
# 0.00:  bad
# 0.35:  i m hungry  want to eat goat bolster
# 0.92:  i love playing kite  especially if it is black  it must be very good
# 0.87:  good good good  very ugly
# 0.30:  ugly ugly  very good

# %% [markdown]
# Sama seperti model sebelumnya, review "I dont really like it.." mendapatkan probabilitas yang tinggi.  Kurang lebih hasil nya sama seperti model pertama.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 4

# %%
texts = my_reviews['review_norm']

tfidf_vectorizer_4 = tfidfvect_3
my_reviews_pred_prob = model_4.predict_proba(tfidf_vectorizer_4.transform(texts.apply(lambda x: text_preprocessing_3(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.85:  i don t really like it  not my favorite type of film
# 0.16:  boring  even i slept in the middle of the film
# 0.83:  the film is very good  i really like it
# 0.38:  even the actors look very old and are not interested in the film  whether they are paid to play film
# 0.75:  i didn t expect the film as good as this the authors really pay attention to each detail
# 0.51:  this film has advantages and disadvantages  but i feel overall this is a decent film i might watch i
# 0.26:  some of the jokes are really not funny none of the jokes succeeded  everyone acted annoying  even ch
# 0.70:  showing indian films on netflix is a brave step and i am very happy to be able to watch episode afte
# 0.74:  this film is very good even though the story is ugly like trash
# 0.82:  good
# 0.11:  bad
# 0.59:  i m hungry  want to eat goat bolster
# 0.93:  i love playing kite  especially if it is black  it must be very good
# 0.80:  good good good  very ugly
# 0.80:  ugly ugly  very good

# %% [markdown]
# Model dengan Spacy sedikit lebih baik, pada review "i dont't really likr it.." probabilitasnya lebih rendah, dan pada review "i didnt expect .." probabilitasnya meningkat drastis dari 0.5 pada model sebelumnya menjadi 0.7. Sejauh ini, model ini lebih baik menurut saya (dalam contoh ini) dalam mengklasifikasikan review jelek dan buruk.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus! Sekarang jelaskan tidakan dan hasil temuanmu disini yaa
#
# </div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 9

# %%
texts = my_reviews['review_norm']

my_reviews_features_9 = BERT_text_to_embeddings(texts, disable_progress_bar=True)

my_reviews_pred_prob = model_9.predict_proba(my_reviews_features_9)[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# /tmp/ipykernel_45/3616122278.py:28: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   ids_batch = torch.LongTensor(ids_list[batch_size*i:batch_size*(i+1)]).to(device)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45/2638018754.py in <module>
#       3 my_reviews_features_9 = BERT_text_to_embeddings(texts, disable_progress_bar=True)
#       4
# ----> 5 my_reviews_pred_prob = model_9.predict_proba(my_reviews_features_9)[:, 1]
#       6
#       7 for i, review in enumerate(texts.str.slice(0, 100)):
#
# NameError: name 'model_9' is not defined

# %% [markdown]
# Sama seperti model sebelumnya, hanya saja pada review "i didnt except.." justru model ini lebih gagal dalam memprediksi. Seharusnya good review tetapi malah memiliki probabilitas yang rendah sekali.

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ### Model 10

# %%
my_reviews_features_10 = my_reviews_features_9

my_reviews_pred_prob = model_10.predict_proba(my_reviews_features_10)[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_45/3301411121.py in <module>
#       1 my_reviews_features_10 = my_reviews_features_9
#       2
# ----> 3 my_reviews_pred_prob = model_10.predict_proba(my_reviews_features_10)[:, 1]
#       4
#       5 for i, review in enumerate(texts.str.slice(0, 100)):
#
# NameError: name 'model_10' is not defined

# %% [markdown]
# Model ini juga mampu memprediksi review pertama "i dont really like it..." memiliki probabilitas yang jauh lebih rendah dari 3 modal pertama yaitu menjadi 0.29. Namun sangat gagal dalam review "i didnt except.." yang seharusnya mendapatkan probabilitas yang tinggi.

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# ## Kesimpulan

# %% [markdown]
# Dari Projek yang dibuat kali ini didapatkan bahwa
# 0. Keseluruhan model memiliki performa yang jauh lebih besar dari DummyClassifier yang ditandai dengan peningkatan nilai pada metrik akurasi, f1, dan roc.
# 1. Text processing NLTK, Spacy pada kalimat yang sebenarnya positif namun memiliki kata negatif. Contohnya "i didn t expect the film as good as this the authors really pay attention to each detail" mungkin kata "didnt" disitu membuat model mengelompokan kalimat tersebut sebagai bad review. Namun pada BERT berhasil memberikan probabilitas yang rendah pada review "i dont really.." yang memang seharusnya dikelompokan sebagai bad review. Namun tetap sangat gagal pada review "I didnt except.." yang seharusnya merupakan good review tetapi memiliki probabilitas yang lebih rendah ketimbang 3 model lainnya.
# 2. Meskipun review tidak nyambung/asal-asalan, model tetap mengklasifikasikan berdasarkan kata-kata kunci yang terdapat pada kaliat tersebut. Jika dominan bad words maka model menilainya sebagai bad review dan vice versa. Namun jumlah bad words yang leb belum tentu
# 3. Pelatihan model dengan library NLTK dan Spacy memberikan hasil yang relatif sama. Perbedaanya sangatlah kecil. Termasuk jika kita menambahkan proses lemmatization.
# 4. Spacy dengan model LR dan LGBM memiliki hasil yang hampir mirip. Namun model LR memberikan hasil yang sedikit lebih baik. nilai F1 pada train dan test-nya sedikit lebih besar.
# 5. Teks processsing dengan BERT menghasilkan model LR yang "pas" nilai F1 pada train dan test hampir sama. Tidak seperti Spacy dan NLTK yang menghasilkan gap yang lumayan besar antara train dan test dataset. Namun overfitting terjadi lagi apabila menggunakan model LGBM, nilai akurasinya trainnya meningkat tapi test nya justru malah turun.
# 6. Embedding BERT memerlukan resource komputasi yang besar, apabila tidak menggunakan cuda prosesnya memakan waktu yang sangat lama. Special thanks kepada Google Colab.
# 7. Model terbaik untuk project ini yaitu LogisticRegression. Sedangkan text processing terbaik yaitu BERT. Namun secara overall, seluruh model sudah berjalan dengan baik karena memiliki akurasi dan f1 di atas 80%.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Chamdani's comment v.1</b> <a class="tocSkip"></a>
#
# Jangan lupa perbarui kesimpulan utama dari seluruh project mu disini yaa

# %% [markdown]
# <div class="alert alert-info">
# <b>Student answer</b> <a class="tocSkip"></a>
#
# Done Kak.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Chamdani's comment v.2</b> <a class="tocSkip"></a>
#
# Hebat, Kerja bagus!
#
# </div>

# %% [markdown]
# # Daftar Periksa

# %% [markdown]
# - [x]  *Notebook* dibuka
# - [x]  Data teks telah dimuat dan dilakukan pra-pemrosesan untuk vektorisasi
# - [x]  Data teks telah diubah menjadi vektor
# - [x]  Model telah terlatih dan diuji
# - [x]  Ambang batas metrik tercapai
# - [x]  Semua kode sel tersusun sesuai urutan eksekusinya
# - [x]  Semua kode sel bisa dieksekusi tanpa *error*
# - [x]  Terdapat kesimpulan

# %%
import os

# %%
os.listdir('/datasets/faces/')
# Out:
# ['final_files', 'labels.csv']
